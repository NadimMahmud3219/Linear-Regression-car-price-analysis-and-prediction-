# %% [markdown]
# <a href="https://colab.research.google.com/github/NadimMahmud3219/Linear-Regression-car-price-analysis-and-prediction-/blob/main/Car_price_analysis%26prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/CarPrice_Assignment.csv")

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
df.shape
# Out:
# (205, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
df.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
df.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
df['CarName'].nunique()
# Out:
# 147

# %%
df[['CarName','price']]
# Out:
#                       CarName    price
# 0          alfa-romero giulia  13495.0
# 1         alfa-romero stelvio  16500.0
# 2    alfa-romero Quadrifoglio  16500.0
# 3                 audi 100 ls  13950.0
# 4                  audi 100ls  17450.0
# ..                        ...      ...
# 200           volvo 145e (sw)  16845.0
# 201               volvo 144ea  19045.0
# 202               volvo 244dl  21485.0
# 203                 volvo 246  22470.0
# 204               volvo 264gl  22625.0
#
# [205 rows x 2 columns]

# %%
df[df['CarName']=='audi 100ls']
# Out:
#    car_ID  symboling     CarName fueltype aspiration doornumber carbody  \
# 4       5          2  audi 100ls      gas        std       four   sedan
# 6       7          1  audi 100ls      gas        std       four   sedan
#
#   drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 4        4wd          front       99.4  ...         136        mpfi
# 6        fwd          front      105.8  ...         136        mpfi
#
#    boreratio  stroke compressionratio horsepower  peakrpm citympg  highwaympg  \
# 4       3.19     3.4              8.0        115     5500      18          22
# 6       3.19     3.4              8.5        110     5500      19          25
#
#      price
# 4  17450.0
# 6  17710.0
#
# [2 rows x 26 columns]

# %%
df[['enginesize','price']]
# Out:
#      enginesize    price
# 0           130  13495.0
# 1           130  16500.0
# 2           152  16500.0
# 3           109  13950.0
# 4           136  17450.0
# ..          ...      ...
# 200         141  16845.0
# 201         141  19045.0
# 202         173  21485.0
# 203         145  22470.0
# 204         141  22625.0
#
# [205 rows x 2 columns]

# %%
df['enginesize'].max()
# Out:
# 326

# %%
df[df['enginesize']==326]
# Out:
#     car_ID  symboling    CarName fueltype aspiration doornumber carbody  \
# 49      50          0  jaguar xk      gas        std        two   sedan
#
#    drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 49        rwd          front      102.0  ...         326        mpfi
#
#     boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 49       3.54    2.76             11.5        262     5000      13
#
#     highwaympg    price
# 49          17  36000.0
#
# [1 rows x 26 columns]

# %%
df['price'].max()
# Out:
# 45400.0

# %%
df[df['price']==45400.0]
# Out:
#     car_ID  symboling                          CarName fueltype aspiration  \
# 74      75          1  buick regal sport coupe (turbo)      gas        std
#
#    doornumber  carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 74        two  hardtop        rwd          front      112.0  ...         304
#
#     fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm  \
# 74        mpfi        3.8    3.35              8.0        184     4500
#
#    citympg  highwaympg    price
# 74      14          16  45400.0
#
# [1 rows x 26 columns]

# %%
df['price'].mean()
# Out:
# 13276.710570731706

# %%
df[df['enginesize']>200]
# Out:
#      car_ID  symboling                          CarName fueltype aspiration  \
# 15       16          0                           bmw x4      gas        std
# 16       17          0                           bmw x5      gas        std
# 17       18          0                           bmw x3      gas        std
# 47       48          0                        jaguar xj      gas        std
# 48       49          0                        jaguar xf      gas        std
# 49       50          0                        jaguar xk      gas        std
# 71       72         -1          buick opel isuzu deluxe      gas        std
# 72       73          3                    buick skylark      gas        std
# 73       74          0            buick century special      gas        std
# 74       75          1  buick regal sport coupe (turbo)      gas        std
# 129     130          1                  porsche cayenne      gas        std
#
# ...

# %%
df['horsepower'].max()
# Out:
# 288

# %%
df['horsepower'].min()
# Out:
# 48

# %%
df[df['horsepower']==288]
# Out:
#      car_ID  symboling          CarName fueltype aspiration doornumber  \
# 129     130          1  porsche cayenne      gas        std        two
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 129  hatchback        rwd          front       98.4  ...         203
#
#      fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm  \
# 129        mpfi       3.94    3.11             10.0        288     5750
#
#     citympg  highwaympg    price
# 129      17          28  31400.5
#
# [1 rows x 26 columns]

# %%
df[df['horsepower']==48]
# Out:
#     car_ID  symboling           CarName fueltype aspiration doornumber  \
# 18      19          2  chevrolet impala      gas        std        two
#
#       carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 18  hatchback        fwd          front       88.4  ...          61
#
#     fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm  \
# 18        2bbl       2.91    3.03              9.5         48     5100
#
#    citympg  highwaympg   price
# 18      47          53  5151.0
#
# [1 rows x 26 columns]

# %%
df[df['horsepower']>180]
# Out:
#      car_ID  symboling                          CarName fueltype aspiration  \
# 15       16          0                           bmw x4      gas        std
# 16       17          0                           bmw x5      gas        std
# 17       18          0                           bmw x3      gas        std
# 49       50          0                        jaguar xk      gas        std
# 73       74          0            buick century special      gas        std
# 74       75          1  buick regal sport coupe (turbo)      gas        std
# 105     106          3                     nissan kicks      gas      turbo
# 126     127          3                porcshce panamera      gas        std
# 127     128          3                  porsche cayenne      gas        std
# 128     129          3                   porsche boxter      gas        std
# 129     130          1                  porsche cayenne      gas        std
#
# ...

# %%
df[(df['price']>=25000)]
# Out:
#      car_ID  symboling                          CarName fueltype aspiration  \
# 15       16          0                           bmw x4      gas        std
# 16       17          0                           bmw x5      gas        std
# 17       18          0                           bmw x3      gas        std
# 47       48          0                        jaguar xj      gas        std
# 48       49          0                        jaguar xf      gas        std
# 49       50          0                        jaguar xk      gas        std
# 67       68         -1         buick electra 225 custom   diesel      turbo
# 68       69         -1         buick century luxus (sw)   diesel      turbo
# 69       70          0                    buick century   diesel      turbo
# 70       71         -1                    buick skyhawk   diesel      turbo
# 71       72         -1          buick opel isuzu deluxe      gas        std
# ...

# %%
df['enginelocation'].unique()
# Out:
# array(['front', 'rear'], dtype=object)

# %%
df[(df['enginelocation']=='front')].head(10)
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
# 5       6          2                  audi fox      gas        std        two
# 6       7          1                audi 100ls      gas        std       four
# 7       8          1                 audi 5000      gas        std       four
# 8       9          1                 audi 4000      gas      turbo       four
# 9      10          0       audi 5000s (diesel)      gas      turbo        two
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# ...

# %%
df[(df['enginelocation']=='rear')].head()
# Out:
#      car_ID  symboling            CarName fueltype aspiration doornumber  \
# 126     127          3  porcshce panamera      gas        std        two
# 127     128          3    porsche cayenne      gas        std        two
# 128     129          3     porsche boxter      gas        std        two
#
#          carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 126      hardtop        rwd           rear       89.5  ...         194
# 127      hardtop        rwd           rear       89.5  ...         194
# 128  convertible        rwd           rear       89.5  ...         194
#
#      fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm  \
# 126        mpfi       3.74     2.9              9.5        207     5900
# 127        mpfi       3.74     2.9              9.5        207     5900
# 128        mpfi       3.74     2.9              9.5        207     5900
#
#     citympg  highwaympg    price
# 126      17          25  32528.0
# ...

# %%
df['fueltype'].unique()
# Out:
# array(['gas', 'diesel'], dtype=object)

# %%
df[(df['fueltype']=='gas')].head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
df[(df['fueltype']=='diesel')].head()
# Out:
#     car_ID  symboling                   CarName fueltype aspiration  \
# 63      64          0          mazda glc deluxe   diesel        std
# 66      67          0             mazda rx-7 gs   diesel        std
# 67      68         -1  buick electra 225 custom   diesel      turbo
# 68      69         -1  buick century luxus (sw)   diesel      turbo
# 69      70          0             buick century   diesel      turbo
#
#    doornumber  carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 63       four    sedan        fwd          front       98.8  ...         122
# 66       four    sedan        rwd          front      104.9  ...         134
# 67       four    sedan        rwd          front      110.0  ...         183
# 68       four    wagon        rwd          front      110.0  ...         183
# 69        two  hardtop        rwd          front      106.7  ...         183
#
#     fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm  \
# ...

# %%
df['aspiration'].unique()
# Out:
# array(['std', 'turbo'], dtype=object)

# %%
df[(df['aspiration']=='std')].head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
df[(df['aspiration']=='turbo')].head()
# Out:
#     car_ID  symboling                    CarName fueltype aspiration  \
# 8        9          1                  audi 4000      gas      turbo
# 9       10          0        audi 5000s (diesel)      gas      turbo
# 23      24          1                 dodge d200      gas      turbo
# 27      28          1       dodge coronet custom      gas      turbo
# 29      30          3  dodge coronet custom (sw)      gas      turbo
#
#    doornumber    carbody drivewheel enginelocation  wheelbase  ...  \
# 8        four      sedan        fwd          front      105.8  ...
# 9         two  hatchback        4wd          front       99.5  ...
# 23        two  hatchback        fwd          front       93.7  ...
# 27        two      sedan        fwd          front       93.7  ...
# 29        two  hatchback        fwd          front       95.9  ...
#
#     enginesize  fuelsystem  boreratio  stroke compressionratio horsepower  \
# ...

# %%
sns.distplot(df['price'],bins=30)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %% [markdown]
# #The maximum number of price is distributed between 8000 to 18000

# %%
sns.violinplot(x='enginesize',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='enginesize', ylabel='price'>

# %%
sns.barplot(
    x='enginesize', 
    y='price', 
    data=df, 
    color='blue');

# %%
sns.relplot(data=df, x="enginesize", y="price", kind="line")

# %%
##from the plot we can easily understand that the price is increased when the size of engine is increased

# %%
sns.relplot(data=df, x="horsepower", y="price", kind="line")

# %%
####from the plot we can easily understand that the price is increased when horsepower is increased

# %%
sns.relplot(data=df, x="peakrpm", y="price", kind="line")

# %%
sns.relplot(data=df, x="highwaympg", y="price", kind="line")

# %% [markdown]
# the price is decreased when the highwaympg is decreased

# %%
sns.relplot(data=df, x="citympg", y="price", kind="line")

# %% [markdown]
# the price is decreased when the citympgis decreased

# %%
sns.relplot(data=df, x="compressionratio", y="price", kind="line")

# %%
sns.relplot(data=df, x="boreratio", y="price", kind="line")

# %% [markdown]
# the price is increased when the boreratio increased

# %%
sns.relplot(data=df, x="wheelbase", y="price", kind="line")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
#Encoding
from sklearn.preprocessing import LabelEncoder

# %%
Encoder = LabelEncoder()

# %%
df['CarName'] = Encoder.fit_transform(df['CarName'])
df['fueltype'] = Encoder.fit_transform(df['fueltype'])
df['aspiration'] = Encoder.fit_transform(df['aspiration'])
df['doornumber'] = Encoder.fit_transform(df['doornumber'])
df['carbody'] = Encoder.fit_transform(df['carbody'])
df['drivewheel'] = Encoder.fit_transform(df['drivewheel'])
df['enginelocation'] = Encoder.fit_transform(df['enginelocation'])
df['enginetype'] = Encoder.fit_transform(df['enginetype'])
df['cylindernumber'] = Encoder.fit_transform(df['cylindernumber'])
df['fuelsystem'] = Encoder.fit_transform(df['fuelsystem'])

# %%
df.drop(columns='car_ID',axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   symboling         205 non-null    int64
#  1   CarName           205 non-null    int64
#  2   fueltype          205 non-null    int64
#  3   aspiration        205 non-null    int64
#  4   doornumber        205 non-null    int64
#  5   carbody           205 non-null    int64
#  6   drivewheel        205 non-null    int64
#  7   enginelocation    205 non-null    int64
#  8   wheelbase         205 non-null    float64
#  9   carlength         205 non-null    float64
#  10  carwidth          205 non-null    float64
#  11  carheight         205 non-null    float64
#  12  curbweight        205 non-null    int64
#  13  enginetype        205 non-null    int64
#  14  cylindernumber    205 non-null    int64
#  15  enginesize        205 non-null    int64
# ...

# %%
x = df.drop(columns=['price'],axis=1)
y = df['price']

# %%
x.head()
# Out:
#    symboling  CarName  fueltype  aspiration  doornumber  carbody  drivewheel  \
# 0          3        2         1           0           1        0           2
# 1          3        3         1           0           1        0           2
# 2          1        1         1           0           1        2           2
# 3          2        4         1           0           0        3           1
# 4          2        5         1           0           0        3           0
#
#    enginelocation  wheelbase  carlength  ...  cylindernumber  enginesize  \
# 0               0       88.6      168.8  ...               2         130
# 1               0       88.6      168.8  ...               2         130
# 2               0       94.5      171.2  ...               3         152
# 3               0       99.8      176.6  ...               2         109
# 4               0       99.4      176.6  ...               1         136
#
# ...

# %%
y.head()
# Out:
# 0    13495.0
# 1    16500.0
# 2    16500.0
# 3    13950.0
# 4    17450.0
# Name: price, dtype: float64

# %%
x.corr()
# Out:
#                   symboling   CarName  fueltype  aspiration  doornumber  \
# symboling          1.000000 -0.107095  0.194311   -0.059866    0.664073
# CarName           -0.107095  1.000000 -0.069435    0.019914   -0.171745
# fueltype           0.194311 -0.069435  1.000000   -0.401397    0.191491
# aspiration        -0.059866  0.019914 -0.401397    1.000000   -0.031792
# doornumber         0.664073 -0.171745  0.191491   -0.031792    1.000000
# carbody           -0.596135  0.099691 -0.147853    0.063028   -0.680358
# drivewheel        -0.041671 -0.016129 -0.132257    0.066465    0.098954
# enginelocation     0.212471  0.055968  0.040070   -0.057191    0.137757
# wheelbase         -0.531954  0.014550 -0.308346    0.257611   -0.447357
# carlength         -0.357612  0.053016 -0.212679    0.234539   -0.398568
# carwidth          -0.232919 -0.075349 -0.233880    0.300567   -0.207168
# carheight         -0.541038  0.201900 -0.284631    0.087311   -0.552208
# ...

# %%
plt.figure(figsize = (15,12))
dataplot = sns.heatmap(x.corr(), annot=True)
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_scaled = sc.fit_transform(x)
from sklearn.decomposition import PCA
pca = PCA(n_components=10)
X_pca = pca.fit_transform(X_scaled)

# %%
X_pca.shape
# Out:
# (205, 10)

# %%
X_pca = pd.DataFrame(X_pca)
X_pca.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.717565  3.655222  1.817448 -0.532166 -2.011579  0.938113 -1.829638
# 1 -0.717570  3.652779  1.815870 -0.519840 -2.022819  0.933616 -1.827266
# 2  0.367128  2.476753  0.694164 -1.082828  2.639673 -0.219219 -0.049685
# 3 -0.166117  0.248695 -0.639872 -1.447938  0.596070 -0.365171  0.086330
# 4  0.693861  0.579908 -1.317522 -2.357941  0.069118  0.727421  1.314274
#
#           7         8         9
# 0 -0.723458  2.174825 -1.209720
# 1 -0.729412  2.165553 -1.205201
# 2 -0.327220  0.133221  0.542297
# 3  0.841178  0.406960  1.056303
# 4  1.409068  0.028924  1.526679

# %%
plt.figure(figsize = (15,12))
dataplot = sns.heatmap(X_pca.corr(), annot=True)
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x_pca_train, x_pca_test, ytrain, ytest = train_test_split(X_pca,y,test_size = 0.20, shuffle= True, random_state=7)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_pca_train,ytrain)
# Out:
# LinearRegression()

# %%
model.score(x_pca_test,ytest)
# Out:
# 0.8691610606638362

# %%
y_pred = model.predict(x_pca_test)

# %%
plt.scatter(y_pred,ytest)

# %%
sns.distplot((ytest-y_pred))
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
mse = mean_squared_error(ytest, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(ytest, y_pred)

# %%
# print the results
print('Regression Coefficients:', model.coef_)
print('Intercept:', model.intercept_)
print('Mean Squared Error:', mse)
print('Root Mean Squared Error:', rmse)
print('R-squared:', r2)
# Out:
# Regression Coefficients: [2327.08940415  872.24946795  759.67245638   68.49560706 1258.89282322
#  1175.2470942  -962.9681379  1870.75876486  621.97170357 -200.68873444]
# Intercept: 13193.134965960366
# Mean Squared Error: 8125289.039494471
# Root Mean Squared Error: 2850.4892631782477
# R-squared: 0.8691610606638362

# %%
model.coef_
# Out:
# array([2327.08940415,  872.24946795,  759.67245638,   68.49560706,
#        1258.89282322, 1175.2470942 , -962.9681379 , 1870.75876486,
#         621.97170357, -200.68873444])
